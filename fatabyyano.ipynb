# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
base_url = 'https://fatabyyano.net'
urls = [base_url] + [f'{base_url}/page/{i}/' for i in range(2, 178)]

# %%
def scrape_page(url):
    page = requests.get(url)
    src = page.content
    soup = BeautifulSoup(src, 'lxml')
    news_details = []
    newsCards = soup.find_all("div", {'class': 'vc_col-sm-8 wpb_column vc_column_container'})
    
    for newsCard in newsCards:
        all_news = newsCard.contents[0].find_all("article")
        fake_keywords = ["مضلل", "زائف", "زائف جزئي"]
        for news in all_news:
            title_news = news.find('h2').text.strip()
            time_news = news.find('time').text.strip()
            span_news = news.find('span').text.strip()

        classification = "fake" if any(keyword in span_news for keyword in fake_keywords) else "real"

        news_details.append({
            "title": title_news,
            "time": time_news,
            "fake or real": classification
            # "topic": 
        })
    
    return news_details

# %%
all_news_details = []
for url in urls:
    print(url)
    all_news_details.extend(scrape_page(url))
# Out:
# https://fatabyyano.net
# https://fatabyyano.net/page/2/
# https://fatabyyano.net/page/3/
# https://fatabyyano.net/page/4/
# https://fatabyyano.net/page/5/
# https://fatabyyano.net/page/6/
# https://fatabyyano.net/page/7/
# https://fatabyyano.net/page/8/
# https://fatabyyano.net/page/9/
# https://fatabyyano.net/page/10/
# https://fatabyyano.net/page/11/
# https://fatabyyano.net/page/12/
# https://fatabyyano.net/page/13/
# https://fatabyyano.net/page/14/
# https://fatabyyano.net/page/15/
# https://fatabyyano.net/page/16/
# https://fatabyyano.net/page/17/
# https://fatabyyano.net/page/18/
# https://fatabyyano.net/page/19/
# https://fatabyyano.net/page/20/
# https://fatabyyano.net/page/21/
# https://fatabyyano.net/page/22/
# https://fatabyyano.net/page/23/
# https://fatabyyano.net/page/24/
# https://fatabyyano.net/page/25/
# https://fatabyyano.net/page/26/
# https://fatabyyano.net/page/27/
# https://fatabyyano.net/page/28/
# https://fatabyyano.net/page/29/
# https://fatabyyano.net/page/30/
# https://fatabyyano.net/page/31/
# https://fatabyyano.net/page/32/
# https://fatabyyano.net/page/33/
# https://fatabyyano.net/page/34/
# https://fatabyyano.net/page/35/
# https://fatabyyano.net/page/36/
# https://fatabyyano.net/page/37/
# https://fatabyyano.net/page/38/
# https://fatabyyano.net/page/39/
# https://fatabyyano.net/page/40/
# https://fatabyyano.net/page/41/
# https://fatabyyano.net/page/42/
# https://fatabyyano.net/page/43/
# https://fatabyyano.net/page/44/
# https://fatabyyano.net/page/45/
# https://fatabyyano.net/page/46/
# https://fatabyyano.net/page/47/
# https://fatabyyano.net/page/48/
# https://fatabyyano.net/page/49/
# https://fatabyyano.net/page/50/
# https://fatabyyano.net/page/51/
# https://fatabyyano.net/page/52/
# https://fatabyyano.net/page/53/
# https://fatabyyano.net/page/54/
# https://fatabyyano.net/page/55/
# https://fatabyyano.net/page/56/
# https://fatabyyano.net/page/57/
# https://fatabyyano.net/page/58/
# https://fatabyyano.net/page/59/
# https://fatabyyano.net/page/60/
# https://fatabyyano.net/page/61/
# https://fatabyyano.net/page/62/
# https://fatabyyano.net/page/63/
# https://fatabyyano.net/page/64/
# https://fatabyyano.net/page/65/
# https://fatabyyano.net/page/66/
# https://fatabyyano.net/page/67/
# https://fatabyyano.net/page/68/
# https://fatabyyano.net/page/69/
# https://fatabyyano.net/page/70/
# https://fatabyyano.net/page/71/
# https://fatabyyano.net/page/72/
# https://fatabyyano.net/page/73/
# https://fatabyyano.net/page/74/
# https://fatabyyano.net/page/75/
# https://fatabyyano.net/page/76/
# https://fatabyyano.net/page/77/
# https://fatabyyano.net/page/78/
# https://fatabyyano.net/page/79/
# https://fatabyyano.net/page/80/
# https://fatabyyano.net/page/81/
# https://fatabyyano.net/page/82/
# https://fatabyyano.net/page/83/
# https://fatabyyano.net/page/84/
# https://fatabyyano.net/page/85/
# https://fatabyyano.net/page/86/
# https://fatabyyano.net/page/87/
# https://fatabyyano.net/page/88/
# https://fatabyyano.net/page/89/
# https://fatabyyano.net/page/90/
# https://fatabyyano.net/page/91/
# https://fatabyyano.net/page/92/
# https://fatabyyano.net/page/93/
# https://fatabyyano.net/page/94/
# https://fatabyyano.net/page/95/
# https://fatabyyano.net/page/96/
# https://fatabyyano.net/page/97/
# https://fatabyyano.net/page/98/
# https://fatabyyano.net/page/99/
# https://fatabyyano.net/page/100/
# https://fatabyyano.net/page/101/
# https://fatabyyano.net/page/102/
# https://fatabyyano.net/page/103/
# https://fatabyyano.net/page/104/
# https://fatabyyano.net/page/105/
# https://fatabyyano.net/page/106/
# https://fatabyyano.net/page/107/
# https://fatabyyano.net/page/108/
# https://fatabyyano.net/page/109/
# https://fatabyyano.net/page/110/
# https://fatabyyano.net/page/111/
# https://fatabyyano.net/page/112/
# https://fatabyyano.net/page/113/
# https://fatabyyano.net/page/114/
# https://fatabyyano.net/page/115/
# https://fatabyyano.net/page/116/
# https://fatabyyano.net/page/117/
# https://fatabyyano.net/page/118/
# https://fatabyyano.net/page/119/
# https://fatabyyano.net/page/120/
# https://fatabyyano.net/page/121/
# https://fatabyyano.net/page/122/
# https://fatabyyano.net/page/123/
# https://fatabyyano.net/page/124/
# https://fatabyyano.net/page/125/
# https://fatabyyano.net/page/126/
# https://fatabyyano.net/page/127/
# https://fatabyyano.net/page/128/
# https://fatabyyano.net/page/129/
# https://fatabyyano.net/page/130/
# https://fatabyyano.net/page/131/
# https://fatabyyano.net/page/132/
# https://fatabyyano.net/page/133/
# https://fatabyyano.net/page/134/
# https://fatabyyano.net/page/135/
# https://fatabyyano.net/page/136/
# https://fatabyyano.net/page/137/
# https://fatabyyano.net/page/138/
# https://fatabyyano.net/page/139/
# https://fatabyyano.net/page/140/
# https://fatabyyano.net/page/141/
# https://fatabyyano.net/page/142/
# https://fatabyyano.net/page/143/
# https://fatabyyano.net/page/144/
# https://fatabyyano.net/page/145/
# https://fatabyyano.net/page/146/
# https://fatabyyano.net/page/147/
# https://fatabyyano.net/page/148/
# https://fatabyyano.net/page/149/
# https://fatabyyano.net/page/150/
# https://fatabyyano.net/page/151/
# https://fatabyyano.net/page/152/
# https://fatabyyano.net/page/153/
# https://fatabyyano.net/page/154/
# https://fatabyyano.net/page/155/
# https://fatabyyano.net/page/156/
# https://fatabyyano.net/page/157/
# https://fatabyyano.net/page/158/
# https://fatabyyano.net/page/159/
# https://fatabyyano.net/page/160/
# https://fatabyyano.net/page/161/
# https://fatabyyano.net/page/162/
# https://fatabyyano.net/page/163/
# https://fatabyyano.net/page/164/
# https://fatabyyano.net/page/165/
# https://fatabyyano.net/page/166/
# https://fatabyyano.net/page/167/
# https://fatabyyano.net/page/168/
# https://fatabyyano.net/page/169/
# https://fatabyyano.net/page/170/
# https://fatabyyano.net/page/171/
# https://fatabyyano.net/page/172/
# https://fatabyyano.net/page/173/
# https://fatabyyano.net/page/174/
# https://fatabyyano.net/page/175/
# https://fatabyyano.net/page/176/
# https://fatabyyano.net/page/177/

# %%
keys = all_news_details[0].keys()
with open('/home/kawther/Documents/S2/NLP/new/BS/news.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_news_details)
    print("File created successfully.")
# Out:
# File created successfully.
